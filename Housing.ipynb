# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
house = pd.read_csv("Housing Data Set.csv")
house.head(10)
# Out:
#         Neighborhood  Sector #  Population (2010)  Total # Units (2000)  \
# 0   Allegheny Center         3                933                   675
# 1     Allegheny West         3                462                   390
# 2          Allentown         6               2500                  1505
# 3          Arlington         7               1869                   880
# 4  Arlington Heights         7                244                   557
# 5         Banksville         5               4144                  2203
# 6  Bedford Dwellings        15               1202                  1049
# 7          Beechview         5               7974                  4048
# 8        Beltzhoover         6               1925                  1298
# 9         Bloomfield        12               8442                  5432
#
#    Total # Units (2010)  % Occupied Units (2010)  % Vacant Units (2010)  \
# 0                  1052                 0.515209               0.484791
# 1                   355                 0.749296               0.250704
# 2                  1291                 0.800155               0.199845
# 3                   886                 0.865688               0.134312
# 4                   148                 0.912162               0.087838
# 5                  2118                 0.954202               0.045798
# 6                   746                 0.872654               0.127346
# 7                  3939                 0.892612               0.107388
# 8                  1085                 0.734562               0.265438
# 9                  5136                 0.890187               0.109813
#
#    # Occupied Units (2010)  % Owner Occupied Units (2010)  \
# 0                      535                       0.100935
# 1                      203                       0.182266
# 2                      953                       0.591815
# 3                      754                       0.653846
# 4                      139                       0.187050
# 5                     2093                       0.498806
# 6                      695                       0.076259
# 7                     3518                       0.587265
# 8                      849                       0.734982
# 9                     4924                       0.366775
#
#    % Renter Occupied Units (2010)  ...  % Units Built before 1939  \
# 0                        0.899065  ...                   0.012821
# 1                        0.817734  ...                   0.574468
# 2                        0.408185  ...                   0.628886
# 3                        0.346154  ...                   0.723205
# 4                        0.812950  ...                   0.092391
# 5                        0.501194  ...                   0.046419
# 6                        0.923741  ...                   0.385902
# 7                        0.412735  ...                   0.426939
# 8                        0.265018  ...                   0.673640
# 9                        0.633225  ...                   0.729601
#
#    Median Home Value (2000)  Med. Val. ('00 in '10 Dollars)  \
# 0                   86500.0                   109535.000000
# 1                  159700.0                   202228.202312
# 2                   34300.0                    43434.109827
# 3                   38800.0                    49132.462428
# 4                   45000.0                    56983.526012
# 5                   87200.0                   110421.410405
# 6                   17200.0                    21780.369942
# 7                   56150.0                    71102.777457
# 8                   34000.0                    43054.219653
# 9                   60560.0                    76687.163006
#
#    Median Home  Value (2010)  % Change Real Value 2000-2010  \
# 0                   136300.0                       0.244351
# 1                   123600.0                      -0.388809
# 2                    42200.0                      -0.028413
# 3                    44200.0                      -0.100391
# 4                    64400.0                       0.130151
# 5                   110900.0                       0.004334
# 6                    81100.0                       2.723536
# 7                    72400.0                       0.018244
# 8                    36000.0                      -0.163845
# 9                    92840.0                       0.210633
#
#    Median Sale Price (2010)  # Sales Counted (2010)  Foreclosures (2008)  \
# 0                       NaN                       0                    0
# 1                  309940.0                       7                    0
# 2                    8500.0                      70                   27
# 3                   15397.0                      34                   12
# 4                       NaN                       0                    0
# 5                  101430.5                      40                    7
# 6                     200.0                       1                    0
# 7                   36067.5                     128                   64
# 8                    2744.0                      39                   12
# 9                   99250.0                     118                   18
#
#    Foreclosures (2010)  % of all Housing Units Foreclosed (2010)
# 0                    0                                  0.000000
# 1                    1                                  0.002817
# 2                   11                                  0.008521
# 3                   13                                  0.014673
# 4                    0                                  0.000000
# 5                    5                                  0.002361
# 6                    1                                  0.001340
# 7                   40                                  0.010155
# 8                   11                                  0.010138
# 9                   12                                  0.002336
#
# [10 rows x 28 columns]

# %% [markdown]
# ## Neighborhood vs. Population

# %%
pop = house.dropna()
pop = pop.iloc[:,[0,2]]
groupedData = pop.groupby('Neighborhood')['Population (2010)'].mean()
groupedData
# Out:
# Neighborhood
# Allegheny West          462
# Allentown              2500
# Arlington              1869
# Banksville             4144
# Bedford Dwellings      1202
#                        ...
# Upper Lawrenceville    2669
# West End                254
# West Oakland           2604
# Westwood               3066
# Windgap                1369
# Name: Population (2010), Length: 83, dtype: int64

# %%
sortPop = pop.sort_values(ascending=False, by = ["Population (2010)"])
topFive = sortPop.head(5)
topTen = sortPop.head(10) #Top 10 most populated neighborhoods

# %%
#Use seaborn or matplotlib to plot a more detailed graph... This is just for show rn
sortPop.head(7).plot.barh(x = "Neighborhood", y = "Population (2010)", color = "green")
sortPop.head(7).plot.bar(x = "Neighborhood", y = "Population (2010)", color = "turquoise")

# %%
box = sb.barplot(x = "Neighborhood", y = "Population (2010)", data = topFive,  palette="Set3", errwidth = 1)
plt.show(box)

# %% [markdown]
# ## Total Units 2000 Vs. 2010

# %%
house = pd.read_csv("Housing Data Set.csv")
house.head(10)
# Out:
#         Neighborhood  Sector #  Population (2010)  Total # Units (2000)  \
# 0   Allegheny Center         3                933                   675
# 1     Allegheny West         3                462                   390
# 2          Allentown         6               2500                  1505
# 3          Arlington         7               1869                   880
# 4  Arlington Heights         7                244                   557
# 5         Banksville         5               4144                  2203
# 6  Bedford Dwellings        15               1202                  1049
# 7          Beechview         5               7974                  4048
# 8        Beltzhoover         6               1925                  1298
# 9         Bloomfield        12               8442                  5432
#
#    Total # Units (2010)  % Occupied Units (2010)  % Vacant Units (2010)  \
# 0                  1052                 0.515209               0.484791
# 1                   355                 0.749296               0.250704
# 2                  1291                 0.800155               0.199845
# 3                   886                 0.865688               0.134312
# 4                   148                 0.912162               0.087838
# 5                  2118                 0.954202               0.045798
# 6                   746                 0.872654               0.127346
# 7                  3939                 0.892612               0.107388
# 8                  1085                 0.734562               0.265438
# 9                  5136                 0.890187               0.109813
#
#    # Occupied Units (2010)  % Owner Occupied Units (2010)  \
# 0                      535                       0.100935
# 1                      203                       0.182266
# 2                      953                       0.591815
# 3                      754                       0.653846
# 4                      139                       0.187050
# 5                     2093                       0.498806
# 6                      695                       0.076259
# 7                     3518                       0.587265
# 8                      849                       0.734982
# 9                     4924                       0.366775
#
#    % Renter Occupied Units (2010)  ...  % Units Built before 1939  \
# 0                        0.899065  ...                   0.012821
# 1                        0.817734  ...                   0.574468
# 2                        0.408185  ...                   0.628886
# 3                        0.346154  ...                   0.723205
# 4                        0.812950  ...                   0.092391
# 5                        0.501194  ...                   0.046419
# 6                        0.923741  ...                   0.385902
# 7                        0.412735  ...                   0.426939
# 8                        0.265018  ...                   0.673640
# 9                        0.633225  ...                   0.729601
#
#    Median Home Value (2000)  Med. Val. ('00 in '10 Dollars)  \
# 0                   86500.0                   109535.000000
# 1                  159700.0                   202228.202312
# 2                   34300.0                    43434.109827
# 3                   38800.0                    49132.462428
# 4                   45000.0                    56983.526012
# 5                   87200.0                   110421.410405
# 6                   17200.0                    21780.369942
# 7                   56150.0                    71102.777457
# 8                   34000.0                    43054.219653
# 9                   60560.0                    76687.163006
#
#    Median Home  Value (2010)  % Change Real Value 2000-2010  \
# 0                   136300.0                       0.244351
# 1                   123600.0                      -0.388809
# 2                    42200.0                      -0.028413
# 3                    44200.0                      -0.100391
# 4                    64400.0                       0.130151
# 5                   110900.0                       0.004334
# 6                    81100.0                       2.723536
# 7                    72400.0                       0.018244
# 8                    36000.0                      -0.163845
# 9                    92840.0                       0.210633
#
#    Median Sale Price (2010)  # Sales Counted (2010)  Foreclosures (2008)  \
# 0                       NaN                       0                    0
# 1                  309940.0                       7                    0
# 2                    8500.0                      70                   27
# 3                   15397.0                      34                   12
# 4                       NaN                       0                    0
# 5                  101430.5                      40                    7
# 6                     200.0                       1                    0
# 7                   36067.5                     128                   64
# 8                    2744.0                      39                   12
# 9                   99250.0                     118                   18
#
#    Foreclosures (2010)  % of all Housing Units Foreclosed (2010)
# 0                    0                                  0.000000
# 1                    1                                  0.002817
# 2                   11                                  0.008521
# 3                   13                                  0.014673
# 4                    0                                  0.000000
# 5                    5                                  0.002361
# 6                    1                                  0.001340
# 7                   40                                  0.010155
# 8                   11                                  0.010138
# 9                   12                                  0.002336
#
# [10 rows x 28 columns]

# %%
pop = house.dropna()
pop = pop.iloc[:,[3,4]]
pop
# Out:
#     Total # Units (2000)  Total # Units (2010)
# 1                    390                   355
# 2                   1505                  1291
# 3                    880                   886
# 5                   2203                  2118
# 6                   1049                   746
# ..                   ...                   ...
# 85                  1504                  1442
# 86                   211                   165
# 87                   638                   687
# 88                  1499                  1496
# 89                   667                   671
#
# [83 rows x 2 columns]

# %%
np.random.seed(19680801)


x = pop["Total # Units (2000)"]
y = pop["Total # Units (2010)"]
s = 200

plt.scatter(x, y, s, c="g", alpha= 0.4, marker=r'$\clubsuit$',
            label="Luck")
plt.xlabel("Total # Units (2000)")
plt.ylabel("Total # Units (2010)")
plt.show()
pop.describe()
# Out:
#        Total # Units (2000)  Total # Units (2010)
# count             83.000000             83.000000
# mean            1936.096386           1852.204819
# std             1625.987134           1652.787990
# min              193.000000            165.000000
# 25%              694.000000            648.000000
# 50%             1505.000000           1469.000000
# 75%             2560.000000           2361.000000
# max             8451.000000           8610.000000
